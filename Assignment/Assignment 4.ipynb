# %%
import numpy as np
import pandas as pd
from scipy import stats

# %%
# que1. Business Problem: A car rental company wants to analyze the rental durations of its customers
#to understand the typical rental period and optimize its pricing andfleet
#management strategies. Data: Let's consider the rental durations (in days) for asample of 50 customers:
A1= np.array([3,2,5,4,7,2,3,3,1,6,4,2,3,5,2,4,2,1,3,5,6,3,2,1,4,2,4,5,3,2,7,2,3,4,5,1,6,2,4,3,5,3,2,4,2,6,3,2,4,5])

# %%
A1
# Out:
# array([3, 2, 5, 4, 7, 2, 3, 3, 1, 6, 4, 2, 3, 5, 2, 4, 2, 1, 3, 5, 6, 3,
#        2, 1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4,
#        2, 6, 3, 2, 4, 5])

# %%
# sum of observation / Total number 
mean = np.mean(A1)
mean
# Out:
# np.float64(3.44)

# %%
# middle value in the dataset
median = np.median(A1)
median
# Out:
# np.float64(3.0)

# %%
# most frequent value in the dataset
mode = stats.mode(A1)
mode
# Out:
# ModeResult(mode=np.int64(2), count=np.int64(13))

# %%
# que2.An e-commerce platform wants to analyze the delivery times of its shipments tounderstand the variability
#in order fulfillment and optimize its logistics operations. Data:
#Let's consider the delivery times (in days) for a sample of 50  shipments.
A2 = np.array([3,5,2,4,6,2,3,4,2,5,7,2,3,4,2,4,2,3,5,6,3,2,1,4,2,4,5,3,2,7,2,3,4,5,1,6,
               2,4,3,5,3,2,4,2,6,3,2,4,5,3])

# %%
A2
# Out:
# array([3, 5, 2, 4, 6, 2, 3, 4, 2, 5, 7, 2, 3, 4, 2, 4, 2, 3, 5, 6, 3, 2,
#        1, 4, 2, 4, 5, 3, 2, 7, 2, 3, 4, 5, 1, 6, 2, 4, 3, 5, 3, 2, 4, 2,
#        6, 3, 2, 4, 5, 3])

# %%
# diffrence between maximum nd minimum value
range = np.max(A2) - np.min(A2)
range
# Out:
# np.int64(6)

# %%
# your data points are spread out.
# deltadegree of freedom 
variance = np.var(A2,ddof= 1)
variance
# Out:
# np.float64(2.336326530612245)

# %%
# how far your data values go away from the average.
SD = np.std(A2)
SD
# Out:
# np.float64(1.513142425550219)

# %%
# Que-3 A company wants to analyze the monthly revenue generated by one of
# its productsto understand its performance and variability.
#Data: Let's consider the monthly revenue (in thousands of dollars) for the past 12months:
revenue = np.array([120,150,110,135,125,140,130,155,115,145,135,130])
revenue
# Out:
# array([120, 150, 110, 135, 125, 140, 130, 155, 115, 145, 135, 130])

# %%
measurect = np.mean(revenue)
measurect
# Out:
# np.float64(132.5)

# %%
measuredes = np.max(revenue) - np.min(revenue)
measuredes
# Out:
# np.int64(45)

# %%
# que-4 #4. A transportation company wants to analyze the fuel efficiency of its
#vehicle fleet toidentify any variations across different vehicle models.
#Data: Let's consider the fuel efficiency (in miles per gallon, mpg) for a sample of 50 vehicles:
Model_A = np.array([30, 32, 33, 28, 31, 30, 29, 30, 32, 31])
Model_B = np.array([25, 27, 26, 23, 28, 24, 26, 25, 27, 28])
Model_C = np.array([22, 23, 20, 25, 21, 24, 23, 22, 25, 24])
Model_D = np.array([18, 17, 19, 20, 21, 18, 19, 17, 20, 19])
Model_E = np.array([35, 36, 34, 35, 33, 34, 32, 33, 36, 34])

# %%
# for model A
r_A = np.max(Model_A) - np.min(Model_A)
v_A = np.var(Model_A) 
m_A = np.mean(Model_A)

r_A,v_A,m_A
# Out:
# (np.int64(5), np.float64(2.0400000000000005), np.float64(30.6))

# %%
# for model B
r_B = np.max(Model_B) - np.min(Model_B)
v_B = np.var(Model_B) 
m_B = np.mean(Model_B)

r_B,v_B,m_B
# Out:
# (np.int64(5), np.float64(2.49), np.float64(25.9))

# %%
# for model C
r_C = np.max(Model_C) - np.min(Model_C)
v_C = np.var(Model_C) 
m_C = np.mean(Model_C)

r_C,v_C,m_C
# Out:
# (np.int64(5), np.float64(2.4899999999999998), np.float64(22.9))

# %%
# for model D
r_D = np.max(Model_D) - np.min(Model_D)
v_D = np.var(Model_D) 
m_D = np.mean(Model_D)

r_D,v_D,m_D
# Out:
# (np.int64(4), np.float64(1.56), np.float64(18.8))

# %%
# for model E
r_E = np.max(Model_E) - np.min(Model_E)
v_E = np.var(Model_E) 
m_E = np.mean(Model_E)

r_E,v_E,m_E
# Out:
# (np.int64(4), np.float64(1.5599999999999998), np.float64(34.2))

# %%
# que-5 # A manufacturing company wants to analyze the defect rates of its
# production line to identify the frequency of different types of defects.
#Data: Let's consider the types of defects and their corresponding frequencies observed in a sample of 200 products:
Defect_Type = ['A','B','C','D','E','F','G']
Frequency = np.array([30,40,20,10,45,25,30])

# %%
# Bar Chart: Create a bar chart to visualize the frequency of different defect types.
import matplotlib.pyplot as plt
plt.bar( Defect_Type , Frequency)
plt.xlabel('Defect_Type')
plt.ylabel('Frequency')
plt.title('frequency of different defect types')
plt.show()

# %%
# b. Most Common Defect: Which defect type has the highest frequency?
# E.

# %%
# c.Histogram: Create a histogram to represent the defect frequencies
plt.hist(Frequency,bins = 5 ,edgecolor = 'black')
plt.title('histogram to represent the defect frequencies')
plt.show()

# %%
# que-6. A survey was conducted to analyze the satisfaction ratings of customers onascaleof 1 to 5 for a specific product.
#Data: Let's consider the satisfaction ratings from 200 customers:
Rating = np.array([4, 5, 3, 4, 4, 3, 2, 5, 4, 3, 5, 4, 2, 3, 4, 5, 3, 4, 5, 3,
                    4, 3, 2, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4,
                    3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3,
                    3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4,
                    5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4])

# %%
Rating
# Out:
# array([4, 5, 3, 4, 4, 3, 2, 5, 4, 3, 5, 4, 2, 3, 4, 5, 3, 4, 5, 3, 4, 3,
#        2, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4, 3, 4, 5, 4,
#        2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5, 4, 3, 3, 4, 5, 2, 3, 4,
#        4, 3, 5, 4, 3, 4, 5, 4, 2, 3, 4, 5, 3, 4, 5, 4, 3, 4, 5, 3, 4, 5,
#        4, 3, 3, 4, 5, 2, 3, 4, 4, 3, 5, 4])

# %%
# a. Skewness: Calculate the skewness of the satisfaction ratings.
skewness = stats.skew(Rating)
skewness
# the direction and amount of asymmetry in the data distribution
# Out:
# np.float64(-0.20773281879682218)

# %%
#b. Kurtosis: Calculate the kurtosis of the satisfaction ratings.
Kurtosis = stats.kurtosis(Rating)
Kurtosis
# quentifies tailedness or peakedness of distribution proability fun.
# Out:
# np.float64(-0.767917404014467)

# %%
# c. Interpretation: Based on the skewness and kurtosis values, what can be inferred about the satisfaction ratings distribution?
if skewness > 0:
    print("The satisfaction ratings are positively skewed.")
elif skewness < 0:
    print("The satisfaction ratings are negatively skewed.")
else:
    print("The satisfaction ratings are symmetric.")
# Out:
# The satisfaction ratings are negatively skewed.

# %%
# que-7 A research study wants to analyze the weight distribution of a sample of individuals to assess their health and body composition.
# # Data: Let's consider the weights (in kilograms) of a sample of 100 individuals:
Weight = np.array([55, 60, 62, 65, 68, 70, 72, 75, 78, 80,82, 85, 88, 90, 92,
                    95, 100, 105, 110, 115,120, 125, 130, 135, 140, 145, 150,
                    155, 160, 165, 170, 175, 180, 185, 190, 195, 200, 205,
                    210, 215, 220, 225, 230, 235, 240, 245, 250,255, 260,
                    265, 270, 275, 280, 285, 290, 295, 300, 305, 310, 315,
                    320, 325, 330, 335, 340,345, 350, 355, 360, 365, 370,
                    375, 380, 385, 390, 395, 400, 405, 410, 415, 420, 425,
                    430, 435, 440, 445, 450, 455, 460, 465, 470, 475,
                    480, 485, 490, 495, 500, 505, 510, 515])

# %%
Weight
# Out:
# array([ 55,  60,  62,  65,  68,  70,  72,  75,  78,  80,  82,  85,  88,
#         90,  92,  95, 100, 105, 110, 115, 120, 125, 130, 135, 140, 145,
#        150, 155, 160, 165, 170, 175, 180, 185, 190, 195, 200, 205, 210,
#        215, 220, 225, 230, 235, 240, 245, 250, 255, 260, 265, 270, 275,
#        280, 285, 290, 295, 300, 305, 310, 315, 320, 325, 330, 335, 340,
#        345, 350, 355, 360, 365, 370, 375, 380, 385, 390, 395, 400, 405,
#        410, 415, 420, 425, 430, 435, 440, 445, 450, 455, 460, 465, 470,
#        475, 480, 485, 490, 495, 500, 505, 510, 515])

# %%
# a. Quartiles: Calculate the first quartile (Q1), median (Q2), and thirdquartile(Q3) of the weight distribution.
Q1 = np.quantile(Weight,0.25)
Q1
# Out:
# np.float64(143.75)

# %%
Q2 = np.quantile(Weight,0.50)
Q2
# Out:
# np.float64(267.5)

# %%
Q3 = np.quantile(Weight,0.75)
Q3
# Out:
# np.float64(391.25)

# %%
# b. Percentiles: Calculate the 15th percentile, 50th percentile, and 85thpercentile of the weight distribution.
pr_15 = np.percentile(Weight,15)
pr_15
# Out:
# np.float64(94.55)

# %%
pr_50 = np.percentile(Weight,50)
pr_50
# Out:
# np.float64(267.5)

# %%
pr_85 = np.percentile(Weight,85)
pr_85
# Out:
# np.float64(440.74999999999994)

# %%
# c. Interpretation: Based on the quartiles and percentiles, what can be inferredabout the weight distribution of the individuals?
if Q1 < Q2 < Q3:
    print("The weight distribution is positively skewed.")
elif Q1 > Q2 > Q3:
    print("The weight distribution is negatively skewed.")
else:
    print("The weight distribution is symmetric.")
# Out:
# The weight distribution is positively skewed.

# %%
#que-8 A researcher wants to examine the relationship between the hours spent studying and the exam scores of a group of students.
#Data: Let's consider the number of hours spent studying and the correspondingexam scores for a sample of 30 students:
Hours_Spent_Studying = ([10, 12, 15, 18, 20, 22, 25, 28, 30, 32, 35, 38, 40, 42, 45, 48, 50, 52, 55, 58, 60, 62, 65, 68,
                      70, 72, 75, 78, 80, 82])
Exam_Scores = ([60, 65, 70, 75, 80, 82, 85, 88, 90, 92, 93, 95, 96, 97, 98,
                      99, 100, 102, 105, 106, 107, 108, 110, 112, 114, 115, 116, 118, 120, 122])
Hours_Spent_Studying , Exam_Scores
# Out:
# ([10,
#   12,
#   15,
#   18,
#   20,
#   22,
#   25,
#   28,
#   30,
#   32,
#   35,
#   38,
#   40,
#   42,
#   45,
#   48,
#   50,
#   52,
#   55,
#   58,
#   60,
#   62,
#   65,
#   68,
#   70,
#   72,
#   75,
#   78,
#   80,
#   82],
#  [60,
#   65,
#   70,
#   75,
#   80,
#   82,
#   85,
#   88,
#   90,
#   92,
#   93,
#   95,
#   96,
#   97,
#   98,
#   99,
#   100,
#   102,
#   105,
#   106,
#   107,
#   108,
#   110,
#   112,
#   114,
#   115,
#   116,
#   118,
#   120,
#   122])

# %%
# Calculate the correlation coefficient between the hours spent studying andtheexam scores. Interpret the value of the
#correlation coefficient and explain the nature of the relationship between studying hours and examscores.
corelation_coefficient = np.corrcoef(Hours_Spent_Studying , Exam_Scores)[0,1]
corelation_coefficient
# Out:
# np.float64(0.9772950830186736)

# %% [markdown]
# #### strong positive corelation between hours spent studying and exam score.

# %%
# que-9. A multiple-choice test consists of 10 questions, each with four possible answers.
# If astudent randomly guesses on each question, what is the probability of gettingat least 8 questions correct?
# Data: Number of questions (n) = 10, Number of possible answers per question (k) = 4
# n = 10
# p = 0.25
# prob = 0

# built-in combination function
from math import comb  

n = 10
p = 1/4
q = 1 - p

prob = 0
for k in range*(8,11):
    term = comb(n, k) * (p ** k) * (q ** (n - k))
    prob += term

prob
# Out:
# 0.0023174285888671875

# %%
# 10. The lifetimes of a certain brand of light bulbs are normally distributed witha meanof 1000 hours and a standard deviation of 100 hours. 
# What is the probabilitythat arandomly selected light bulb lasts between 900 and 1100 hours? Data: Meanlifetime(μ) = 1000 hours, Standard deviation (σ) 
# = 100 hours, Lifetime range (lower limit x1, upper limit x2)

from scipy.stats import norm

mean = 1000        
std_dev = 100      
x1 = 900           
x2 = 1100

p1 = norm.cdf(x1,mean,std_dev)
p2 = norm.cdf(x2,mean,std_dev)

prob = p2-p1
prob
# Out:
# np.float64(0.6826894921370859)

# %%
# 11. A study is conducted to estimate the mean height of a population. Arandomsampleof 100 individuals is selected, and their heights are measured.
# Calculate a 95%confidence interval for the population mean height, given that the sample meanheight is 170 cm and the sample standard deviation is 8 cm.
# Data: Sample size(n) =100, Sample mean (x̄) = 170 cm, Sample standard deviation (s) = 8 cm, Confidencelevel = 95%Explanation: 
# In this problem, we use a sample to estimate the populationmeanheight. By calculating a confidence interval, we provide a range of plausiblevalues 
# for the population mean. The 95% confidence level indicates that weare95% confident that the true population mean height 
# falls within the calculatedinterval

from math import sqrt
from scipy.stats import norm

n = 100
x_bar = 170
s = 8
confidence = 0.95

z = norm.ppf(0.975)   
margin_error = z * (s / sqrt(n))

lower = x_bar - margin_error
upper = x_bar + margin_error

print("95% Confidence Interval = (", round(lower, 3), ",", round(upper, 3), ")")
# Out:
# 95% Confidence Interval = ( 168.432 , 171.568 )

# %%
# 12. A manufacturing company claims that the average weight of its product is 500grams. To test this claim, a random sample of 25 products is selected,
# and their weights are measured. The sample mean weight is found to be 510 grams withasample standard deviation of 20 grams. Perform a hypothesis test 
# to determineif there is evidence to support the company's claim.
# Data: Sample size (n) =25, Sample mean (x̄) = 510 grams, Sample standard deviation (s) = 20 grams, Population mean (μ) = 500 grams

# Explanation: In this problem, we are conducting a hypothesis test to assess
# whether the sample mean weight provides evidence to support the company's
# claim about the population mean weight. The null hypothesis (H0) assumes that
# the population mean weight is equal to the claimed value, while the alternativehypothesis (Ha) suggests otherwise.

from math import sqrt
from scipy.stats import t

# Step 1: Given data
n = 25
x_bar = 510
s = 20
mu = 500
alpha = 0.05   # 95% confidence level

# Step 2: Calculate t-statistic
t_stat = (x_bar - mu) / (s / sqrt(n))

# Step 3: Degrees of freedom
df = n - 1

# Step 4: Find critical t-value for two-tailed test
t_critical = t.ppf(1 - alpha/2, df)

# Step 5: Decision
print("Calculated t =", round(t_stat, 3))
print("Critical t =", round(t_critical, 3))

if abs(t_stat) > t_critical:
    print(" Reject H0: There is evidence that mean ≠ 500 grams.")
else:
    print(" Fail to Reject H0: Company’s claim seems valid.")
# Out:
# Calculated t = 2.5
# Critical t = 2.064
#  Reject H0: There is evidence that mean ≠ 500 grams.

# %%
# 13.A researcher wants to test whether a new teaching method improves student
# performance. A random sample of 50 students is divided into two groups: onegrouptaught using the new method and the other using the traditional method.
# The averagetest scores of the two groups are compared. State the null and alternative hypothesesfor this study. 
# Data: Sample size (n) = 50, Test scores of the two groups
# Explanation: In this problem, we are interested in comparing the means of twogroups (new method vs. traditional method). 
# The null hypothesis (H0) states that
# there is no significant difference between the means, while the alternative
# hypothesis (Ha) suggests that there is a significant difference


from scipy.stats import ttest_ind

# Step 1️ — Sample data (example test scores)
# Group 1 = New method, Group 2 = Traditional method
new_method = [78, 82, 85, 88, 90, 76, 84, 86, 89, 91,
              77, 80, 83, 85, 87, 90, 88, 82, 84, 86,
              85, 87, 89, 90, 92]

traditional_method = [72, 74, 75, 70, 78, 76, 74, 77, 79, 75,
                      73, 71, 74, 75, 76, 72, 74, 70, 73, 75,
                      74, 76, 72, 75, 74]

# Step 2️ — Perform independent t-test
t_stat, p_value = ttest_ind(new_method, traditional_method)

# Step 3️ — Display results
print("t-statistic =", round(t_stat, 3))
print("p-value =", round(p_value, 4))

# Step 4️ — Decision
alpha = 0.05   # significance level
if p_value < alpha:
    print(" Reject H0: Significant difference exists between the two methods.")
else:
    print(" Fail to Reject H0: No significant difference between the methods.")
# Out:
# t-statistic = 11.38
# p-value = 0.0
#  Reject H0: Significant difference exists between the two methods.

# %%
# 14. A survey is conducted to estimate the proportion of people in a city who support aparticular policy. A random sample of 500 individuals is surveyed,
# and 320of themexpress support for the policy. Calculate a 90% confidence interval for the
# population proportion, given the sample proportion. Data: Sample size (n) =500, Number of successes (x) = 320, Confidence level = 90%
# Explanation: In this problem, we aim to estimate the population proportionbasedon the sample proportion. By constructing a confidence interval, 
# we providearange of plausible values for the population proportion. The 90%confidencelevel
# indicates that we are 90% confident that the true population proportion falls
# within the calculated interval.

#  Practical: 90% Confidence Interval for Population Proportion

from math import sqrt
from scipy.stats import norm

# Step 1️ — Given data
n = 500
x = 320
confidence = 0.90

# Step 2️ — Sample proportion
p_hat = x / n

# Step 3️ — Z value for 90% confidence
z = norm.ppf(0.95)   # 90% → 5% each tail → 0.95 cumulative

# Step 4️ — Margin of error
margin_error = z * sqrt((p_hat * (1 - p_hat)) / n)

# Step 5️ — Confidence interval
lower = p_hat - margin_error
upper = p_hat + margin_error

# Step 6️ — Display results
print("Sample proportion =", round(p_hat, 3))
print("Z-value =", round(z, 3))
print("Margin of Error =", round(margin_error, 4))
print("90% Confidence Interval = (", round(lower, 4), ",", round(upper, 4), ")")
print("In Percentage = (", round(lower*100, 2), "% ,", round(upper*100, 2), "% )")
# Out:
# Sample proportion = 0.64
# Z-value = 1.645
# Margin of Error = 0.0353
# 90% Confidence Interval = ( 0.6047 , 0.6753 )
# In Percentage = ( 60.47 % , 67.53 % )

# %%
# 15. A company sells smartphones, and the number of defects per batch follows a
# Poisson distribution with a mean of 2 defects. What is the probability of havingexactly 3 defects in a randomly selected batch? 
# Data: Mean number of defects (λ) =2, Number of defects (x) = 3
# Explanation: The problem involves a discrete distribution (Poisson) becauseweare dealing with the count of defects in a batch of smartphones. 
# The Poisson distribution models the probability of a given number of events occurringwithinafixed interval of time or space.

from math import exp, factorial

# Step 1️ — Given data
lam = 2    # mean (λ)
x = 3      # number of defects

# Step 2️ — Apply Poisson formula
prob = (exp(-lam) * (lam ** x)) / factorial(x)

# Step 3️ — Display result

print("Probability of exactly 3 defects =", round(prob, 4))
print("In percentage =", round(prob * 100, 2), "%")
# Out:
# Probability of exactly 3 defects = 0.1804
# In percentage = 18.04 %

# %%
"""Explain Key Statistical Concepts"""
# Out:
# 'Explain Key Statistical Concepts'

# %%
"""Key statistical concepts involve Descriptive Statistics (summarizing data with mean, median, mode, variance)
 and Inferential Statistics (using samples to infer about populations, involving hypothesis testing, regression, probability).
   Understanding Population vs. Sample, Central Tendency, Variability, Probability, Correlation, and Regression helps transform raw data into actionable insights for decision-making across various fields. 
Foundational Concepts
Data: Raw observations or measurements from the environment.
Population: The entire group you want to study.
Sample: A smaller, representative subset of the population.
Descriptive Statistics: Methods to organize, summarize, and describe data (e.g., charts, averages).
Inferential Statistics: Methods to make predictions or inferences about a population from a sample. 
Measures of Central Tendency (Where data centers)
Mean: The average (sum of values / number of values).
Median: The middle value in an ordered dataset.
Mode: The most frequently occurring value. 
Measures of Variability/Dispersion (How spread out data is) 
Variance: Measures how far data points are from the mean (squared).
Standard Deviation: The square root of the variance, indicating typical distance from the mean. 
Relationships & Predictions
Probability: The likelihood of an event occurring (e.g., coin toss).
Correlation: Measures the strength and direction of a linear relationship between two variables (e.g., advertising spend vs. sales).
Regression: Models the relationship between a dependent variable and one or more independent variables to make predictions. """
# Out:
# 'Key statistical concepts involve Descriptive Statistics (summarizing data with mean, median, mode, variance)\n and Inferential Statistics (using samples to infer about populations, involving hypothesis testing, regression, probability).\n   Understanding Population vs. Sample, Central Tendency, Variability, Probability, Correlation, and Regression helps transform raw data into actionable insights for decision-making across various fields. \nFoundational Concepts\nData: Raw observations or measurements from the environment.\nPopulation: The entire group you want to study.\nSample: A smaller, representative subset of the population.\nDescriptive Statistics: Methods to organize, summarize, and describe data (e.g., charts, averages).\nInferential Statistics: Methods to make predictions or inferences about a population from a sample. \nMeasures of Central Tendency (Where data centers)\nMean: The average (sum of values / number of values).\nMedian: The middle value in an ordered dataset.\
# ...
